# %%
###-- Google Driveに同期 --###
from google.colab import drive
drive.mount('/content/drive')

# %%
###------------------------------###
###           入力項目            ###
###------------------------------###
##-- CSVファイル名（訓練データ、テストデータ）
train_filename, test_filename = "train_data.csv", "test_data.csv"
##-- Data PATH
PATH_data = "drive/My Drive/data/"
##-- Data Submit
PATH_submit = "drive/My Drive/submit/"
##-- Rondom state
random_state = 99

# %%
###-------------------------------------------###
###        必要なライブラリの読み込み             ###
###-------------------------------------------###
##-- Pandas(CSVファイルの読み込み/処理)
import pandas as pd
from pandas import Series, DataFrame
pd.set_option('max_columns', 300)
pd.set_option('display.max_columns', 300)
pd.set_option('max_rows', 300)
pd.set_option('display.max_rows', 300)
##-- Numpy(数値計算用の配列)
import numpy as np
##-- Matplotlib(グラフの描画)
import matplotlib.pylab as plt
import matplotlib.cm as cm # グラデーション
import seaborn as sns
##-- Scikit-learn(重回帰処理)
import sklearn  #-- print(sklearn.__version__)

##-- Warning非表示
import warnings
warnings.filterwarnings('ignore')

plt.style.use('bmh')
from itertools import cycle
color_cycle = cycle(plt.rcParams['axes.prop_cycle'].by_key()['color'])

# %%
###---------------------------------------------###
###        CSVファイルからプロセスを読み込む         ###
###---------------------------------------------###
f = pd.read_csv(PATH_data+"/"+train_filename, encoding="utf-8")
g = pd.read_csv(PATH_data+"/"+test_filename, encoding="utf-8")
##-- 対数をとっている
f["y"] = np.log(f["y"])

# %% [markdown]
# 前処理

# %%
mean_ = f[["categoryId", "y"]].groupby("categoryId").mean().reset_index().rename({"y":"mean"}, axis=1)
max_ = f[["categoryId", "y"]].groupby("categoryId").max().reset_index().rename({"y":"max"}, axis=1)
min_ = f[["categoryId", "y"]].groupby("categoryId").min().reset_index().rename({"y":"min"}, axis=1)
std_ = f[["categoryId", "y"]].groupby("categoryId").std().reset_index().rename({"y":"std"}, axis=1)
count_ = f[["categoryId", "y"]].groupby("categoryId").count().reset_index().rename({"y":"count"}, axis=1)
q1_ = f[["categoryId", "y"]].groupby("categoryId").quantile(0.1).reset_index().rename({"y":"q1"}, axis=1)
q25_ = f[["categoryId", "y"]].groupby("categoryId").quantile(0.25).reset_index().rename({"y":"q25"}, axis=1)
q5_ = f[["categoryId", "y"]].groupby("categoryId").quantile(0.5).reset_index().rename({"y":"q5"}, axis=1)
q75_ = f[["categoryId", "y"]].groupby("categoryId").quantile(0.75).reset_index().rename({"y":"q75"}, axis=1)
q9_ = f[["categoryId", "y"]].groupby("categoryId").quantile(0.9).reset_index().rename({"y":"q9"}, axis=1)


def is_japanese(string):
    for ch in string:
        try:
            name = unicodedata.name(ch) 
            if "CJK UNIFIED" in name \
            or "HIRAGANA" in name \
            or "KATAKANA" in name:
                return True
        except:
          continue
    return False

Y = f["y"]
del f["y"]

##-- Dataを結合
data = pd.concat([f, g])
print(data.shape)  # 19720 + 29582 = 49302

data["tags"].fillna("[none]", inplace=True)
tagdic = dict(pd.Series("|".join(list(data["tags"])).split("|")).value_counts().sort_values())
# Out:
# (49302, 16)

# %%
##-- 正規表現 https://docs.python.org/3/library/re.html
import re

def bool_to_int(df):
  df["comments_disabled"] = df["comments_disabled"].astype(np.int16)
  df["ratings_disabled"] = df["ratings_disabled"].astype(np.int16)
  return df

def create_features(df):
  ##--  like dislike comment
  df["likes2"] = df["likes"]**2
  df["loglikes"] = np.log(df["likes"]+1)
  df["dislikes2"] = df["dislikes"]**2
  df["logdislikes"] = np.log(df["dislikes"]+1)
  df["logcomment_count"] = np.log(df["comment_count"]+1)
  df["sqrtlikes"] = np.sqrt(df["likes"])
  df["like_dislike_ratio"] = df["likes"]/(df["dislikes"]+1)
  df["comments_like_ratio"] = df["comment_count"]/(df["likes"]+1)
  df["comments_dislike_ratio"] = df["comment_count"]/(df["dislikes"]+1)

  ##-- likes comments diable
  df["likes_com"] = df["likes"] * df["comments_disabled"]
  df["dislikes_com"] = df["dislikes"] * df["comments_disabled"]
  df["comments_likes"] = df["comment_count"] * df["ratings_disabled"]

  ##-- tags
  df["num_tags"] = df["tags"].astype(str).apply(lambda x: len(x.split("|")))
  df["length_tags"] = df["tags"].astype(str).apply(lambda x: len(x))
  df["tags_point"] = df["tags"].apply(lambda tags: sum([tagdic[tag] for tag in tags.split("|")]))
  df["count_en_tag"] = df["tags"].apply(lambda x: sum([bool(re.search(r'[a-zA-Z0-9]', x_)) for x_ in x.split("|")]))
  df["count_ja_tag"] = df["tags"].apply(lambda x: sum([is_japanese(x_) for x_ in x.split("|")]))

  ##-- publishedAt
  df["publishedAt"] = pd.to_datetime(df["publishedAt"], utc=True)
  df["publishedAt_year"] = df["publishedAt"].apply(lambda x: x.year)
  df["publishedAt_month"] = df["publishedAt"].apply(lambda x: x.month)
  df["publishedAt_day"] = df["publishedAt"].apply(lambda x: x.day)
  df["publishedAt_hour"] = df["publishedAt"].apply(lambda x: x.hour)
  df["publishedAt_minute"] = df["publishedAt"].apply(lambda x: x.minute)
  df["publishedAt_second"] = df["publishedAt"].apply(lambda x: x.second)
  df["publishedAt_dayofweek"] = df["publishedAt"].apply(lambda x: x.dayofweek)

  ##-- collection_date
  df["collection_date_year"] = df["collection_date"].apply(lambda x: int(x[0:2]))
  ##-- 20 --> 2020年に直す
  df["collection_date_year"] = df["collection_date_year"] + 2000
  ##--
  df["collection_date_month"] = df["collection_date"].apply(lambda x: int(x[3:5]))
  df["collection_date_day"] = df["collection_date"].apply(lambda x: int(x[6:8]))
  df["collection_date"] = pd.to_datetime("20"+df["collection_date"], format="%Y.%d.%m", utc=True)

  ##-- delta
  df["delta"] = (df["collection_date"] - df["publishedAt"]).apply(lambda x: x.days)
  df["logdelta"] = np.log(df["delta"])
  df["sqrtdelta"] = np.sqrt(df["delta"])
  df["published_delta"] = (df["publishedAt"] - df["publishedAt"].min()).apply(lambda x: x.days)
  df["collection_delta"] = (df["collection_date"] - df["collection_date"].min()).apply(lambda x: x.days)

  df["description"].fillna(" ", inplace=True)
  df["ishttp_in_dis"] = df["description"].apply(lambda x: x.lower().count("http"))
  df["len_description"] = df["description"].apply(lambda x: len(x))

  df["title"].fillna(" ", inplace=True)
  df["len_title"] = df["title"].apply(lambda x: len(x))

  ##-- is japanese
  df["isJa_title"] = df["title"].apply(lambda x: is_japanese(x))
  df["isJa_tags"] = df["tags"].apply(lambda x: is_japanese(x))
  df["isJa_description"] = df["description"].apply(lambda x: is_japanese(x))

  ##-- is englosh
  df["onEn_tags"] = df["tags"].apply(lambda x: x.encode('utf-8').isalnum())
  df["onEn_description"] = df["description"].apply(lambda x: x.encode('utf-8').isalnum())

  ##-- cotain englosh
  df["conEn_title"] = df["title"].apply(lambda x: len(re.findall(r'[a-zA-Z0-9]', x.lower())))
  df["conEn_tags"] = df["tags"].apply(lambda x: len(re.findall(r'[a-zA-Z0-9]', x.lower())))
  df["conEn_description"] = df["description"].apply(lambda x: len(re.findall(r'[a-zA-Z0-9]', x.lower())))


  df = df.merge(mean_, how='left', on=["categoryId"])
  df = df.merge(max_, how='left', on=["categoryId"])
  df = df.merge(min_, how='left', on=["categoryId"])
  df = df.merge(std_, how='left', on=["categoryId"])
  df = df.merge(q1_, how='left', on=["categoryId"])
  df = df.merge(q25_, how='left', on=["categoryId"])
  df = df.merge(q5_, how='left', on=["categoryId"])
  df = df.merge(q75_, how='left', on=["categoryId"])
  df = df.merge(q9_, how='left', on=["categoryId"])

  # 出現頻度
  for col in ["categoryId", "channelTitle"]:
    freq = df[col].value_counts()
    df["freq_"+col] = df[col].map(freq)

  return df

# %%
###-- 特徴量を一挙作成
data = bool_to_int(data)
data = create_features(data)

# %%
###-- 特徴量（公開されている時間（hour））, Google検索値を使用
data["period_hour"] = 8760*(data["collection_date_year"] - data["publishedAt_year"]) \
                      + 730*(data["collection_date_month"] - data["publishedAt_month"]) \
                      + 24*(data["collection_date_day"] - data["publishedAt_day"])

# %%
del data["channelId"]
del data["video_id"]
del data["title"]
del data["description"]
del data["thumbnail_link"]
del data["channelTitle"]
del data["tags"]
del data["publishedAt"]
del data["collection_date"]
del data["id"]

# %%
##-- Feature importance 0 のcolumnsを削除
del data["logdislikes"]
del data["dislikes2"]
del data["loglikes"]
del data["count_ja_tag"]
del data["logcomment_count"]
del data["likes2"]
del data["isJa_description"]
del data["isJa_tags"]
del data["isJa_title"]
del data["sqrtlikes"]
del data["sqrtdelta"]
del data["logdelta"]

# %%
data.head()
# data.describe()
# Out:
#    categoryId  likes  dislikes  comment_count  comments_disabled  \
# 0          20    114         0              7                  0
# 1          10   2885        50            111                  0
# 2          24    133        17             14                  0
# 3          22    287        51            173                  0
# 4          10    178         6             17                  0
#
#    ratings_disabled  like_dislike_ratio  comments_like_ratio  \
# 0                 0          114.000000             0.060870
# 1                 0           56.568627             0.038462
# 2                 0            7.388889             0.104478
# 3                 0            5.519231             0.600694
# 4                 0           25.428571             0.094972
#
#    comments_dislike_ratio  likes_com  dislikes_com  comments_likes  num_tags  \
# 0                7.000000          0             0               0        48
# 1                2.176471          0             0               0        19
# 2                0.777778          0             0               0         9
# 3                3.326923          0             0               0         1
# 4                2.428571          0             0               0        12
#
#    length_tags  tags_point  count_en_tag  publishedAt_year  publishedAt_month  \
# 0          315        5434            47              2011                  1
# 1          129          76             5              2012                  7
# 2           52          49             6              2007                  7
# 3            6           2             1              2005                  5
# 4           83         850             2              2007                  9
#
#    publishedAt_day  publishedAt_hour  publishedAt_minute  publishedAt_second  \
# 0                9                 5                  50                  33
# 1               23                 3                   0                   9
# 2               26                13                  54                   9
# 3               15                 2                  38                  43
# 4                9                 9                  52                  47
#
#    publishedAt_dayofweek  collection_date_year  collection_date_month  \
# 0                      6                  2020                      1
# 1                      0                  2020                      8
# 2                      3                  2020                     14
# 3                      6                  2019                     22
# 4                      6                  2020                      8
#
#    collection_date_day  delta  published_delta  collection_delta  \
# 0                    2   3309             2086                41
# 1                    2   2755             2646                48
# 2                    1   4554              823                23
# 3                   12   5333               20                 0
# 4                    1   4503              868                17
#
#    ishttp_in_dis  len_description  len_title  onEn_tags  onEn_description  \
# 0              0               61         42      False             False
# 1              1              261         35      False             False
# 2              1               45         22      False             False
# 3              0               30         20       True             False
# 4              2              138         13      False             False
#
#    conEn_title  conEn_tags  conEn_description       mean        max       min  \
# 0           19         258                 38  12.746174  16.787970  3.871201
# 1           18          38                 54  13.155115  20.987221  1.791759
# 2           11          33                 36  12.621979  19.241236  1.098612
# 3           17           6                 21  11.934383  17.548095  2.079442
# 4            0          10                 79  13.155115  20.987221  1.791759
#
#         std         q1        q25         q5        q75         q9  \
# 0  1.794815  10.331027  11.707977  12.980648  13.965945  14.772192
# 1  2.345023  10.297022  11.692096  13.236976  14.651161  15.922321
# 2  2.240565   9.784028  11.271160  12.789547  14.163681  15.277146
# 3  2.559307   8.288986  10.549596  12.196820  13.755893  15.006330
# 4  2.345023  10.297022  11.692096  13.236976  14.651161  15.922321
#
#    freq_categoryId  freq_channelTitle  period_hour
# 0             2275                  1        78672
# 1            17253                  5        70306
# 2             6873                  1       118390
# 3             2207                 10       134978
# 4            17253                  2       112958

# %% [markdown]
# 訓練・検証データセットの準備

# %%
##-- 数値変数
nume_cols = [\
              #-- "***"(int64)
              "likes",\
              #-- "***"(int64)
              "dislikes",\
              #-- "***"(int64)
              "comment_count",\
              "like_dislike_ratio",\
              "comments_like_ratio",\
              "comments_dislike_ratio",\
              "num_tags",\
              "tags_point",\
              "count_en_tag",\
              "len_description",\
              "len_title",\
              "conEn_title",\
              "conEn_tags",\
              "conEn_description",\
              #-- "***"(float64)
              "length_tags",\
              #-- "***"(float64)
              "period_hour",\
             ]
##-- カテゴリカル変数
cat_cols = [\
              #-- "***"(int64)
              "categoryId",\
              "freq_categoryId",\
              "freq_channelTitle",\
              # "isJa_title",\
              # "isJa_tags",\
              # "isJa_description",\
              "onEn_tags",\
              "onEn_description",\
              "ishttp_in_dis",\
            ]

# %%
##-- 交互作用の作成
def interaction(df, nume_cols):
  k = 0
  for i in range(len(nume_cols)):
      for j in range(len(nume_cols)):
          if i == j:
              pass
          else:
              k += 1
              ##-- 積
              name_seki = "feature_seki" + str(k)
              df[name_seki] = df[nume_cols[i]]*df[nume_cols[j]]
              ##-- 商
              name_shou = "feature_shou" + str(k)
              df[name_shou] = df[nume_cols[i]]*df[nume_cols[j]]
              ##-- 差
              name_sa = "feature_sa" + str(k)
              df[name_sa] = df[nume_cols[i]]*df[nume_cols[j]]
  return df
data = interaction(data, nume_cols)
# X.head()

# %%
data.head()
# Out:
#    categoryId  likes  dislikes  comment_count  comments_disabled  \
# 0          20    114         0              7                  0
# 1          10   2885        50            111                  0
# 2          24    133        17             14                  0
# 3          22    287        51            173                  0
# 4          10    178         6             17                  0
#
#    ratings_disabled  like_dislike_ratio  comments_like_ratio  \
# 0                 0          114.000000             0.060870
# 1                 0           56.568627             0.038462
# 2                 0            7.388889             0.104478
# 3                 0            5.519231             0.600694
# 4                 0           25.428571             0.094972
#
#    comments_dislike_ratio  likes_com  dislikes_com  comments_likes  num_tags  \
# 0                7.000000          0             0               0        48
# 1                2.176471          0             0               0        19
# 2                0.777778          0             0               0         9
# 3                3.326923          0             0               0         1
# 4                2.428571          0             0               0        12
#
#    length_tags  tags_point  count_en_tag  publishedAt_year  publishedAt_month  \
# 0          315        5434            47              2011                  1
# 1          129          76             5              2012                  7
# 2           52          49             6              2007                  7
# 3            6           2             1              2005                  5
# 4           83         850             2              2007                  9
#
#    publishedAt_day  publishedAt_hour  publishedAt_minute  publishedAt_second  \
# 0                9                 5                  50                  33
# 1               23                 3                   0                   9
# 2               26                13                  54                   9
# 3               15                 2                  38                  43
# 4                9                 9                  52                  47
#
#    publishedAt_dayofweek  collection_date_year  collection_date_month  \
# 0                      6                  2020                      1
# 1                      0                  2020                      8
# 2                      3                  2020                     14
# 3                      6                  2019                     22
# 4                      6                  2020                      8
#
#    collection_date_day  delta  published_delta  collection_delta  \
# 0                    2   3309             2086                41
# 1                    2   2755             2646                48
# 2                    1   4554              823                23
# 3                   12   5333               20                 0
# 4                    1   4503              868                17
#
#    ishttp_in_dis  len_description  len_title  onEn_tags  onEn_description  \
# 0              0               61         42      False             False
# 1              1              261         35      False             False
# 2              1               45         22      False             False
# 3              0               30         20       True             False
# 4              2              138         13      False             False
#
#    conEn_title  conEn_tags  conEn_description       mean        max       min  \
# 0           19         258                 38  12.746174  16.787970  3.871201
# 1           18          38                 54  13.155115  20.987221  1.791759
# 2           11          33                 36  12.621979  19.241236  1.098612
# 3           17           6                 21  11.934383  17.548095  2.079442
# 4            0          10                 79  13.155115  20.987221  1.791759
#
#         std         q1        q25         q5        q75         q9  \
# 0  1.794815  10.331027  11.707977  12.980648  13.965945  14.772192
# 1  2.345023  10.297022  11.692096  13.236976  14.651161  15.922321
# 2  2.240565   9.784028  11.271160  12.789547  14.163681  15.277146
# 3  2.559307   8.288986  10.549596  12.196820  13.755893  15.006330
# 4  2.345023  10.297022  11.692096  13.236976  14.651161  15.922321
#
#    freq_categoryId  freq_channelTitle  period_hour  feature_seki1  \
# 0             2275                  1        78672              0
# 1            17253                  5        70306         144250
# 2             6873                  1       118390           2261
# 3             2207                 10       134978          14637
# 4            17253                  2       112958           1068
#
#    feature_shou1  feature_sa1  feature_seki2  feature_shou2  feature_sa2  \
# 0              0            0            798            798          798
# 1         144250       144250         320235         320235       320235
# 2           2261         2261           1862           1862         1862
# 3          14637        14637          49651          49651        49651
# 4           1068         1068           3026           3026         3026
#
#    feature_seki3  feature_shou3    feature_sa3  feature_seki4  feature_shou4  \
# 0   12996.000000   12996.000000   12996.000000       6.939130       6.939130
# 1  163200.490196  163200.490196  163200.490196     110.961538     110.961538
# 2     982.722222     982.722222     982.722222      13.895522      13.895522
# 3    1584.019231    1584.019231    1584.019231     172.399306     172.399306
# 4    4526.285714    4526.285714    4526.285714      16.905028      16.905028
#
#    feature_sa4  feature_seki5  feature_shou5  feature_sa5  feature_seki6  \
# 0     6.939130     798.000000     798.000000   798.000000           5472
# 1   110.961538    6279.117647    6279.117647  6279.117647          54815
# 2    13.895522     103.444444     103.444444   103.444444           1197
# 3   172.399306     954.826923     954.826923   954.826923            287
# 4    16.905028     432.285714     432.285714   432.285714           2136
#
#    feature_shou6  feature_sa6  feature_seki7  feature_shou7  feature_sa7  \
# 0           5472         5472         619476         619476       619476
# 1          54815        54815         219260         219260       219260
# 2           1197         1197           6517           6517         6517
# 3            287          287            574            574          574
# 4           2136         2136         151300         151300       151300
#
#    feature_seki8  feature_shou8  feature_sa8  feature_seki9  feature_shou9  \
# 0           5358           5358         5358           6954           6954
# 1          14425          14425        14425         752985         752985
# 2            798            798          798           5985           5985
# 3            287            287          287           8610           8610
# 4            356            356          356          24564          24564
#
#    feature_sa9  feature_seki10  feature_shou10  feature_sa10  feature_seki11  \
# 0         6954            4788            4788          4788            2166
# 1       752985          100975          100975        100975           51930
# 2         5985            2926            2926          2926            1463
# 3         8610            5740            5740          5740            4879
# 4        24564            2314            2314          2314               0
#
#    feature_shou11  feature_sa11  feature_seki12  feature_shou12  feature_sa12  \
# 0            2166          2166           29412           29412         29412
# 1           51930         51930          109630          109630        109630
# 2            1463          1463            4389            4389          4389
# 3            4879          4879            1722            1722          1722
# 4               0             0            1780            1780          1780
#
#    feature_seki13  feature_shou13  feature_sa13  feature_seki14  \
# 0            4332            4332          4332           35910
# 1          155790          155790        155790          372165
# 2            4788            4788          4788            6916
# 3            6027            6027          6027            1722
# 4           14062           14062         14062           14774
#
#    feature_shou14  feature_sa14  feature_seki15  feature_shou15  feature_sa15  \
# 0           35910         35910         8968608         8968608       8968608
# 1          372165        372165       202832810       202832810     202832810
# 2            6916          6916        15745870        15745870      15745870
# 3            1722          1722        38738686        38738686      38738686
# 4           14774         14774        20106524        20106524      20106524
#
#    feature_seki16  feature_shou16  feature_sa16  feature_seki17  \
# 0               0               0             0               0
# 1          144250          144250        144250            5550
# 2            2261            2261          2261             238
# 3           14637           14637         14637            8823
# 4            1068            1068          1068             102
#
#    feature_shou17  feature_sa17  feature_seki18  feature_shou18  feature_sa18  \
# 0               0             0        0.000000        0.000000      0.000000
# 1            5550          5550     2828.431373     2828.431373   2828.431373
# 2             238           238      125.611111      125.611111    125.611111
# 3            8823          8823      281.480769      281.480769    281.480769
# 4             102           102      152.571429      152.571429    152.571429
#
#    feature_seki19  feature_shou19  feature_sa19  feature_seki20  \
# 0        0.000000        0.000000      0.000000        0.000000
# 1        1.923077        1.923077      1.923077      108.823529
# 2        1.776119        1.776119      1.776119       13.222222
# 3       30.635417       30.635417     30.635417      169.673077
# 4        0.569832        0.569832      0.569832       14.571429
#
#    feature_shou20  feature_sa20  feature_seki21  feature_shou21  feature_sa21  \
# 0        0.000000      0.000000               0               0             0
# 1      108.823529    108.823529             950             950           950
# 2       13.222222     13.222222             153             153           153
# 3      169.673077    169.673077              51              51            51
# 4       14.571429     14.571429              72              72            72
#
#    feature_seki22  feature_shou22  feature_sa22  feature_seki23  \
# 0               0               0             0               0
# 1            3800            3800          3800             250
# 2             833             833           833             102
# 3             102             102           102              51
# 4            5100            5100          5100              12
#
#    feature_shou23  feature_sa23  feature_seki24  feature_shou24  feature_sa24  \
# 0               0             0               0               0             0
# 1             250           250           13050           13050         13050
# 2             102           102             765             765           765
# 3              51            51            1530            1530          1530
# 4              12            12             828             828           828
#
#    feature_seki25  feature_shou25  feature_sa25  feature_seki26  \
# 0               0               0             0               0
# 1            1750            1750          1750             900
# 2             374             374           374             187
# 3            1020            1020          1020             867
# 4              78              78            78               0
#
#    feature_shou26  feature_sa26  feature_seki27  feature_shou27  feature_sa27  \
# 0               0             0               0               0             0
# 1             900           900            1900            1900          1900
# 2             187           187             561             561           561
# 3             867           867             306             306           306
# 4               0             0              60              60            60
#
#    feature_seki28  feature_shou28  feature_sa28  feature_seki29  \
# 0               0               0             0               0
# 1            2700            2700          2700            6450
# 2             612             612           612             884
# 3            1071            1071          1071             306
# 4             474             474           474             498
#
#    feature_shou29  feature_sa29  feature_seki30  feature_shou30  feature_sa30  \
# 0               0             0               0               0             0
# 1            6450          6450         3515300         3515300       3515300
# 2             884           884         2012630         2012630       2012630
# 3             306           306         6883878         6883878       6883878
# 4             498           498          677748          677748        677748
#
#    feature_seki31  feature_shou31  feature_sa31  feature_seki32  \
# 0             798             798           798               0
# 1          320235          320235        320235            5550
# 2            1862            1862          1862             238
# 3           49651           49651         49651            8823
# 4            3026            3026          3026             102
#
#    feature_shou32  feature_sa32  feature_seki33  feature_shou33  feature_sa33  \
# 0               0             0      798.000000      798.000000    798.000000
# 1            5550          5550     6279.117647     6279.117647   6279.117647
# 2             238           238      103.444444      103.444444    103.444444
# 3            8823          8823      954.826923      954.826923    954.826923
# 4             102           102      432.285714      432.285714    432.285714
#
#    feature_seki34  feature_shou34  ...  feature_seki191  feature_shou191  \
# 0        0.426087        0.426087  ...            10836            10836
# 1        4.269231        4.269231  ...             1330             1330
# 2        1.462687        1.462687  ...              726              726
# 3      103.920139      103.920139  ...              120              120
# 4        1.614525        1.614525  ...              130              130
#
#    feature_sa191  feature_seki192  feature_shou192  feature_sa192  \
# 0          10836             4902             4902           4902
# 1           1330              684              684            684
# 2            726              363              363            363
# 3            120              102              102            102
# 4            130                0                0              0
#
#    feature_seki193  feature_shou193  feature_sa193  feature_seki194  \
# 0             9804             9804           9804            81270
# 1             2052             2052           2052             4902
# 2             1188             1188           1188             1716
# 3              126              126            126               36
# 4              790              790            790              830
#
#    feature_shou194  feature_sa194  feature_seki195  feature_shou195  \
# 0            81270          81270         20297376         20297376
# 1             4902           4902          2671628          2671628
# 2             1716           1716          3906870          3906870
# 3               36             36           809868           809868
# 4              830            830          1129580          1129580
#
#    feature_sa195  feature_seki196  feature_shou196  feature_sa196  \
# 0       20297376             4332             4332           4332
# 1        2671628           155790           155790         155790
# 2        3906870             4788             4788           4788
# 3         809868             6027             6027           6027
# 4        1129580            14062            14062          14062
#
#    feature_seki197  feature_shou197  feature_sa197  feature_seki198  \
# 0                0                0              0              266
# 1             2700             2700           2700             5994
# 2              612              612            612              504
# 3             1071             1071           1071             3633
# 4              474              474            474             1343
#
#    feature_shou198  feature_sa198  feature_seki199  feature_shou199  \
# 0              266            266      4332.000000      4332.000000
# 1             5994           5994      3054.705882      3054.705882
# 2              504            504       266.000000       266.000000
# 3             3633           3633       115.903846       115.903846
# 4             1343           1343      2008.857143      2008.857143
#
#    feature_sa199  feature_seki200  feature_shou200  feature_sa200  \
# 0    4332.000000         2.313043         2.313043       2.313043
# 1    3054.705882         2.076923         2.076923       2.076923
# 2     266.000000         3.761194         3.761194       3.761194
# 3     115.903846        12.614583        12.614583      12.614583
# 4    2008.857143         7.502793         7.502793       7.502793
#
#    feature_seki201  feature_shou201  feature_sa201  feature_seki202  \
# 0       266.000000       266.000000     266.000000             1824
# 1       117.529412       117.529412     117.529412             1026
# 2        28.000000        28.000000      28.000000              324
# 3        69.865385        69.865385      69.865385               21
# 4       191.857143       191.857143     191.857143              948
#
#    feature_shou202  feature_sa202  feature_seki203  feature_shou203  \
# 0             1824           1824           206492           206492
# 1             1026           1026             4104             4104
# 2              324            324             1764             1764
# 3               21             21               42               42
# 4              948            948            67150            67150
#
#    feature_sa203  feature_seki204  feature_shou204  feature_sa204  \
# 0         206492             1786             1786           1786
# 1           4104              270              270            270
# 2           1764              216              216            216
# 3             42               21               21             21
# 4          67150              158              158            158
#
#    feature_seki205  feature_shou205  feature_sa205  feature_seki206  \
# 0             2318             2318           2318             1596
# 1            14094            14094          14094             1890
# 2             1620             1620           1620              792
# 3              630              630            630              420
# 4            10902            10902          10902             1027
#
#    feature_shou206  feature_sa206  feature_seki207  feature_shou207  \
# 0             1596           1596              722              722
# 1             1890           1890              972              972
# 2              792            792              396              396
# 3              420            420              357              357
# 4             1027           1027                0                0
#
#    feature_sa207  feature_seki208  feature_shou208  feature_sa208  \
# 0            722             9804             9804           9804
# 1            972             2052             2052           2052
# 2            396             1188             1188           1188
# 3            357              126              126            126
# 4              0              790              790            790
#
#    feature_seki209  feature_shou209  feature_sa209  feature_seki210  \
# 0            11970            11970          11970          2989536
# 1             6966             6966           6966          3796524
# 2             1872             1872           1872          4262040
# 3              126              126            126          2834538
# 4             6557             6557           6557          8923682
#
#    feature_shou210  feature_sa210  feature_seki211  feature_shou211  \
# 0          2989536        2989536            35910            35910
# 1          3796524        3796524           372165           372165
# 2          4262040        4262040             6916             6916
# 3          2834538        2834538             1722             1722
# 4          8923682        8923682            14774            14774
#
#    feature_sa211  feature_seki212  feature_shou212  feature_sa212  \
# 0          35910                0                0              0
# 1         372165             6450             6450           6450
# 2           6916              884              884            884
# 3           1722              306              306            306
# 4          14774              498              498            498
#
#    feature_seki213  feature_shou213  feature_sa213  feature_seki214  \
# 0             2205             2205           2205     35910.000000
# 1            14319            14319          14319      7297.352941
# 2              728              728            728       384.222222
# 3             1038             1038           1038        33.115385
# 4             1411             1411           1411      2110.571429
#
#    feature_shou214  feature_sa214  feature_seki215  feature_shou215  \
# 0     35910.000000   35910.000000        19.173913        19.173913
# 1      7297.352941    7297.352941         4.961538         4.961538
# 2       384.222222     384.222222         5.432836         5.432836
# 3        33.115385      33.115385         3.604167         3.604167
# 4      2110.571429    2110.571429         7.882682         7.882682
#
#    feature_sa215  feature_seki216  feature_shou216  feature_sa216  \
# 0      19.173913      2205.000000      2205.000000    2205.000000
# 1       4.961538       280.764706       280.764706     280.764706
# 2       5.432836        40.444444        40.444444      40.444444
# 3       3.604167        19.961538        19.961538      19.961538
# 4       7.882682       201.571429       201.571429     201.571429
#
#    feature_seki217  feature_shou217  feature_sa217  feature_seki218  \
# 0            15120            15120          15120          1711710
# 1             2451             2451           2451             9804
# 2              468              468            468             2548
# 3                6                6              6               12
# 4              996              996            996            70550
#
#    feature_shou218  feature_sa218  feature_seki219  feature_shou219  \
# 0          1711710        1711710            14805            14805
# 1             9804           9804              645              645
# 2             2548           2548              312              312
# 3               12             12                6                6
# 4            70550          70550              166              166
#
#    feature_sa219  feature_seki220  feature_shou220  feature_sa220  \
# 0          14805            19215            19215          19215
# 1            645            33669            33669          33669
# 2            312             2340             2340           2340
# 3              6              180              180            180
# 4            166            11454            11454          11454
#
#    feature_seki221  feature_shou221  feature_sa221  feature_seki222  \
# 0            13230            13230          13230             5985
# 1             4515             4515           4515             2322
# 2             1144             1144           1144              572
# 3              120              120            120              102
# 4             1079             1079           1079                0
#
#    feature_shou222  feature_sa222  feature_seki223  feature_shou223  \
# 0             5985           5985            81270            81270
# 1             2322           2322             4902             4902
# 2              572            572             1716             1716
# 3              102            102               36               36
# 4                0              0              830              830
#
#    feature_sa223  feature_seki224  feature_shou224  feature_sa224  \
# 0          81270            11970            11970          11970
# 1           4902             6966             6966           6966
# 2           1716             1872             1872           1872
# 3             36              126              126            126
# 4            830             6557             6557           6557
#
#    feature_seki225  feature_shou225  feature_sa225  feature_seki226  \
# 0         24781680         24781680       24781680          8968608
# 1          9069474          9069474        9069474        202832810
# 2          6156280          6156280        6156280         15745870
# 3           809868           809868         809868         38738686
# 4          9375514          9375514        9375514         20106524
#
#    feature_shou226  feature_sa226  feature_seki227  feature_shou227  \
# 0          8968608        8968608                0                0
# 1        202832810      202832810          3515300          3515300
# 2         15745870       15745870          2012630          2012630
# 3         38738686       38738686          6883878          6883878
# 4         20106524       20106524           677748           677748
#
#    feature_sa227  feature_seki228  feature_shou228  feature_sa228  \
# 0              0           550704           550704         550704
# 1        3515300          7803966          7803966        7803966
# 2        2012630          1657460          1657460        1657460
# 3        6883878         23351194         23351194       23351194
# 4         677748          1920286          1920286        1920286
#
#    feature_seki229  feature_shou229  feature_sa229  feature_seki230  \
# 0     8.968608e+06     8.968608e+06   8.968608e+06      4788.730435
# 1     3.977114e+06     3.977114e+06   3.977114e+06      2704.076923
# 2     8.747706e+05     8.747706e+05   8.747706e+05     12369.104478
# 3     7.449747e+05     7.449747e+05   7.449747e+05     81080.534722
# 4     2.872361e+06     2.872361e+06   2.872361e+06     10727.854749
#
#    feature_shou230  feature_sa230  feature_seki231  feature_shou231  \
# 0      4788.730435    4788.730435    550704.000000    550704.000000
# 1      2704.076923    2704.076923    153018.941176    153018.941176
# 2     12369.104478   12369.104478     92081.111111     92081.111111
# 3     81080.534722   81080.534722    449061.423077    449061.423077
# 4     10727.854749   10727.854749    274326.571429    274326.571429
#
#    feature_sa231  feature_seki232  feature_shou232  feature_sa232  \
# 0  550704.000000          3776256          3776256        3776256
# 1  153018.941176          1335814          1335814        1335814
# 2   92081.111111          1065510          1065510        1065510
# 3  449061.423077           134978           134978         134978
# 4  274326.571429          1355496          1355496        1355496
#
#    feature_seki233  feature_shou233  feature_sa233  feature_seki234  \
# 0        427503648        427503648      427503648          3697584
# 1          5343256          5343256        5343256           351530
# 2          5801110          5801110        5801110           710340
# 3           269956           269956         269956           134978
# 4         96014300         96014300       96014300           225916
#
#    feature_shou234  feature_sa234  feature_seki235  feature_shou235  \
# 0          3697584        3697584          4798992          4798992
# 1           351530         351530         18349866         18349866
# 2           710340         710340          5327550          5327550
# 3           134978         134978          4049340          4049340
# 4           225916         225916         15588204         15588204
#
#    feature_sa235  feature_seki236  feature_shou236  feature_sa236  \
# 0        4798992          3304224          3304224        3304224
# 1       18349866          2460710          2460710        2460710
# 2        5327550          2604580          2604580        2604580
# 3        4049340          2699560          2699560        2699560
# 4       15588204          1468454          1468454        1468454
#
#    feature_seki237  feature_shou237  feature_sa237  feature_seki238  \
# 0          1494768          1494768        1494768         20297376
# 1          1265508          1265508        1265508          2671628
# 2          1302290          1302290        1302290          3906870
# 3          2294626          2294626        2294626           809868
# 4                0                0              0          1129580
#
#    feature_shou238  feature_sa238  feature_seki239  feature_shou239  \
# 0         20297376       20297376          2989536          2989536
# 1          2671628        2671628          3796524          3796524
# 2          3906870        3906870          4262040          4262040
# 3           809868         809868          2834538          2834538
# 4          1129580        1129580          8923682          8923682
#
#    feature_sa239  feature_seki240  feature_shou240  feature_sa240
# 0        2989536         24781680         24781680       24781680
# 1        3796524          9069474          9069474        9069474
# 2        4262040          6156280          6156280        6156280
# 3        2834538           809868           809868         809868
# 4        8923682          9375514          9375514        9375514
#
# [5 rows x 769 columns]

# %%
###-- データセットのメモリ削減 --###
##-- Ref. https://www.kaggle.com/fabiendaniel/elo-world
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

print('start size: {:5.2f} Mb'.format(data.memory_usage().sum() / 1024**2))
data = reduce_mem_usage(data)
# Out:
# start size: 288.41 Mb
# Mem. usage decreased to 148.11 Mb (48.6% reduction)

# %%
##-- Label Encoding for categorical variable
from sklearn import preprocessing

for name in cat_cols:
  ##-- 学習データに基づいて定義する
  le = preprocessing.LabelEncoder()
  ##-- 訓練とテスト用の併せたカテゴリーにする
  # X_fit = X[name].append(X_pre[name])
  # le.fit(X_fit)
  le.fit(data[name])

  data[name] = le.transform(data[name])

data.head()
# Out:
#    categoryId  likes  dislikes  comment_count  comments_disabled  \
# 0           6    114         0              7                  0
# 1           2   2885        50            111                  0
# 2           9    133        17             14                  0
# 3           7    287        51            173                  0
# 4           2    178         6             17                  0
#
#    ratings_disabled  like_dislike_ratio  comments_like_ratio  \
# 0                 0          114.000000             0.060883
# 1                 0           56.562500             0.038452
# 2                 0            7.390625             0.104492
# 3                 0            5.519531             0.600586
# 4                 0           25.421875             0.094971
#
#    comments_dislike_ratio  likes_com  dislikes_com  comments_likes  num_tags  \
# 0                7.000000          0             0               0        48
# 1                2.175781          0             0               0        19
# 2                0.777832          0             0               0         9
# 3                3.326172          0             0               0         1
# 4                2.427734          0             0               0        12
#
#    length_tags  tags_point  count_en_tag  publishedAt_year  publishedAt_month  \
# 0          315        5434            47              2011                  1
# 1          129          76             5              2012                  7
# 2           52          49             6              2007                  7
# 3            6           2             1              2005                  5
# 4           83         850             2              2007                  9
#
#    publishedAt_day  publishedAt_hour  publishedAt_minute  publishedAt_second  \
# 0                9                 5                  50                  33
# 1               23                 3                   0                   9
# 2               26                13                  54                   9
# 3               15                 2                  38                  43
# 4                9                 9                  52                  47
#
#    publishedAt_dayofweek  collection_date_year  collection_date_month  \
# 0                      6                  2020                      1
# 1                      0                  2020                      8
# 2                      3                  2020                     14
# 3                      6                  2019                     22
# 4                      6                  2020                      8
#
#    collection_date_day  delta  published_delta  collection_delta  \
# 0                    2   3309             2086                41
# 1                    2   2755             2646                48
# 2                    1   4554              823                23
# 3                   12   5333               20                 0
# 4                    1   4503              868                17
#
#    ishttp_in_dis  len_description  len_title  onEn_tags  onEn_description  \
# 0              0               61         42          0                 0
# 1              1              261         35          0                 0
# 2              1               45         22          0                 0
# 3              0               30         20          1                 0
# 4              2              138         13          0                 0
#
#    conEn_title  conEn_tags  conEn_description      mean        max       min  \
# 0           19         258                 38  12.75000  16.781250  3.871094
# 1           18          38                 54  13.15625  20.984375  1.791992
# 2           11          33                 36  12.62500  19.234375  1.098633
# 3           17           6                 21  11.93750  17.546875  2.080078
# 4            0          10                 79  13.15625  20.984375  1.791992
#
#         std         q1        q25         q5        q75         q9  \
# 0  1.794922  10.328125  11.710938  12.984375  13.968750  14.773438
# 1  2.345703  10.296875  11.695312  13.234375  14.648438  15.921875
# 2  2.240234   9.781250  11.273438  12.789062  14.164062  15.273438
# 3  2.558594   8.289062  10.546875  12.195312  13.757812  15.007812
# 4  2.345703  10.296875  11.695312  13.234375  14.648438  15.921875
#
#    freq_categoryId  freq_channelTitle  period_hour  feature_seki1  \
# 0               12                  0        78672              0
# 1               17                  4        70306         144250
# 2               16                  0       118390           2261
# 3               11                  9       134978          14637
# 4               17                  1       112958           1068
#
#    feature_shou1  feature_sa1  feature_seki2  feature_shou2  feature_sa2  \
# 0              0            0            798            798          798
# 1         144250       144250         320235         320235       320235
# 2           2261         2261           1862           1862         1862
# 3          14637        14637          49651          49651        49651
# 4           1068         1068           3026           3026         3026
#
#    feature_seki3  feature_shou3    feature_sa3  feature_seki4  feature_shou4  \
# 0   12996.000000   12996.000000   12996.000000       6.939130       6.939130
# 1  163200.484375  163200.484375  163200.484375     110.961540     110.961540
# 2     982.722229     982.722229     982.722229      13.895522      13.895522
# 3    1584.019287    1584.019287    1584.019287     172.399307     172.399307
# 4    4526.285645    4526.285645    4526.285645      16.905027      16.905027
#
#    feature_sa4  feature_seki5  feature_shou5  feature_sa5  feature_seki6  \
# 0     6.939130     798.000000     798.000000   798.000000           5472
# 1   110.961540    6279.117676    6279.117676  6279.117676          54815
# 2    13.895522     103.444443     103.444443   103.444443           1197
# 3   172.399307     954.826904     954.826904   954.826904            287
# 4    16.905027     432.285706     432.285706   432.285706           2136
#
#    feature_shou6  feature_sa6  feature_seki7  feature_shou7  feature_sa7  \
# 0           5472         5472         619476         619476       619476
# 1          54815        54815         219260         219260       219260
# 2           1197         1197           6517           6517         6517
# 3            287          287            574            574          574
# 4           2136         2136         151300         151300       151300
#
#    feature_seki8  feature_shou8  feature_sa8  feature_seki9  feature_shou9  \
# 0           5358           5358         5358           6954           6954
# 1          14425          14425        14425         752985         752985
# 2            798            798          798           5985           5985
# 3            287            287          287           8610           8610
# 4            356            356          356          24564          24564
#
#    feature_sa9  feature_seki10  feature_shou10  feature_sa10  feature_seki11  \
# 0         6954            4788            4788          4788            2166
# 1       752985          100975          100975        100975           51930
# 2         5985            2926            2926          2926            1463
# 3         8610            5740            5740          5740            4879
# 4        24564            2314            2314          2314               0
#
#    feature_shou11  feature_sa11  feature_seki12  feature_shou12  feature_sa12  \
# 0            2166          2166           29412           29412         29412
# 1           51930         51930          109630          109630        109630
# 2            1463          1463            4389            4389          4389
# 3            4879          4879            1722            1722          1722
# 4               0             0            1780            1780          1780
#
#    feature_seki13  feature_shou13  feature_sa13  feature_seki14  \
# 0            4332            4332          4332           35910
# 1          155790          155790        155790          372165
# 2            4788            4788          4788            6916
# 3            6027            6027          6027            1722
# 4           14062           14062         14062           14774
#
#    feature_shou14  feature_sa14  feature_seki15  feature_shou15  feature_sa15  \
# 0           35910         35910         8968608         8968608       8968608
# 1          372165        372165       202832810       202832810     202832810
# 2            6916          6916        15745870        15745870      15745870
# 3            1722          1722        38738686        38738686      38738686
# 4           14774         14774        20106524        20106524      20106524
#
#    feature_seki16  feature_shou16  feature_sa16  feature_seki17  \
# 0               0               0             0               0
# 1          144250          144250        144250            5550
# 2            2261            2261          2261             238
# 3           14637           14637         14637            8823
# 4            1068            1068          1068             102
#
#    feature_shou17  feature_sa17  feature_seki18  feature_shou18  feature_sa18  \
# 0               0             0        0.000000        0.000000      0.000000
# 1            5550          5550     2828.431396     2828.431396   2828.431396
# 2             238           238      125.611115      125.611115    125.611115
# 3            8823          8823      281.480774      281.480774    281.480774
# 4             102           102      152.571426      152.571426    152.571426
#
#    feature_seki19  feature_shou19  feature_sa19  feature_seki20  \
# 0        0.000000        0.000000      0.000000        0.000000
# 1        1.923077        1.923077      1.923077      108.823532
# 2        1.776119        1.776119      1.776119       13.222222
# 3       30.635416       30.635416     30.635416      169.673080
# 4        0.569832        0.569832      0.569832       14.571428
#
#    feature_shou20  feature_sa20  feature_seki21  feature_shou21  feature_sa21  \
# 0        0.000000      0.000000               0               0             0
# 1      108.823532    108.823532             950             950           950
# 2       13.222222     13.222222             153             153           153
# 3      169.673080    169.673080              51              51            51
# 4       14.571428     14.571428              72              72            72
#
#    feature_seki22  feature_shou22  feature_sa22  feature_seki23  \
# 0               0               0             0               0
# 1            3800            3800          3800             250
# 2             833             833           833             102
# 3             102             102           102              51
# 4            5100            5100          5100              12
#
#    feature_shou23  feature_sa23  feature_seki24  feature_shou24  feature_sa24  \
# 0               0             0               0               0             0
# 1             250           250           13050           13050         13050
# 2             102           102             765             765           765
# 3              51            51            1530            1530          1530
# 4              12            12             828             828           828
#
#    feature_seki25  feature_shou25  feature_sa25  feature_seki26  \
# 0               0               0             0               0
# 1            1750            1750          1750             900
# 2             374             374           374             187
# 3            1020            1020          1020             867
# 4              78              78            78               0
#
#    feature_shou26  feature_sa26  feature_seki27  feature_shou27  feature_sa27  \
# 0               0             0               0               0             0
# 1             900           900            1900            1900          1900
# 2             187           187             561             561           561
# 3             867           867             306             306           306
# 4               0             0              60              60            60
#
#    feature_seki28  feature_shou28  feature_sa28  feature_seki29  \
# 0               0               0             0               0
# 1            2700            2700          2700            6450
# 2             612             612           612             884
# 3            1071            1071          1071             306
# 4             474             474           474             498
#
#    feature_shou29  feature_sa29  feature_seki30  feature_shou30  feature_sa30  \
# 0               0             0               0               0             0
# 1            6450          6450         3515300         3515300       3515300
# 2             884           884         2012630         2012630       2012630
# 3             306           306         6883878         6883878       6883878
# 4             498           498          677748          677748        677748
#
#    feature_seki31  feature_shou31  feature_sa31  feature_seki32  \
# 0             798             798           798               0
# 1          320235          320235        320235            5550
# 2            1862            1862          1862             238
# 3           49651           49651         49651            8823
# 4            3026            3026          3026             102
#
#    feature_shou32  feature_sa32  feature_seki33  feature_shou33  feature_sa33  \
# 0               0             0      798.000000      798.000000    798.000000
# 1            5550          5550     6279.117676     6279.117676   6279.117676
# 2             238           238      103.444443      103.444443    103.444443
# 3            8823          8823      954.826904      954.826904    954.826904
# 4             102           102      432.285706      432.285706    432.285706
#
#    feature_seki34  feature_shou34  ...  feature_seki191  feature_shou191  \
# 0        0.426087        0.426087  ...            10836            10836
# 1        4.269231        4.269231  ...             1330             1330
# 2        1.462687        1.462687  ...              726              726
# 3      103.920135      103.920135  ...              120              120
# 4        1.614525        1.614525  ...              130              130
#
#    feature_sa191  feature_seki192  feature_shou192  feature_sa192  \
# 0          10836             4902             4902           4902
# 1           1330              684              684            684
# 2            726              363              363            363
# 3            120              102              102            102
# 4            130                0                0              0
#
#    feature_seki193  feature_shou193  feature_sa193  feature_seki194  \
# 0             9804             9804           9804            81270
# 1             2052             2052           2052             4902
# 2             1188             1188           1188             1716
# 3              126              126            126               36
# 4              790              790            790              830
#
#    feature_shou194  feature_sa194  feature_seki195  feature_shou195  \
# 0            81270          81270         20297376         20297376
# 1             4902           4902          2671628          2671628
# 2             1716           1716          3906870          3906870
# 3               36             36           809868           809868
# 4              830            830          1129580          1129580
#
#    feature_sa195  feature_seki196  feature_shou196  feature_sa196  \
# 0       20297376             4332             4332           4332
# 1        2671628           155790           155790         155790
# 2        3906870             4788             4788           4788
# 3         809868             6027             6027           6027
# 4        1129580            14062            14062          14062
#
#    feature_seki197  feature_shou197  feature_sa197  feature_seki198  \
# 0                0                0              0              266
# 1             2700             2700           2700             5994
# 2              612              612            612              504
# 3             1071             1071           1071             3633
# 4              474              474            474             1343
#
#    feature_shou198  feature_sa198  feature_seki199  feature_shou199  \
# 0              266            266      4332.000000      4332.000000
# 1             5994           5994      3054.705811      3054.705811
# 2              504            504       266.000000       266.000000
# 3             3633           3633       115.903847       115.903847
# 4             1343           1343      2008.857178      2008.857178
#
#    feature_sa199  feature_seki200  feature_shou200  feature_sa200  \
# 0    4332.000000         2.313044         2.313044       2.313044
# 1    3054.705811         2.076923         2.076923       2.076923
# 2     266.000000         3.761194         3.761194       3.761194
# 3     115.903847        12.614583        12.614583      12.614583
# 4    2008.857178         7.502793         7.502793       7.502793
#
#    feature_seki201  feature_shou201  feature_sa201  feature_seki202  \
# 0       266.000000       266.000000     266.000000             1824
# 1       117.529411       117.529411     117.529411             1026
# 2        28.000000        28.000000      28.000000              324
# 3        69.865387        69.865387      69.865387               21
# 4       191.857147       191.857147     191.857147              948
#
#    feature_shou202  feature_sa202  feature_seki203  feature_shou203  \
# 0             1824           1824           206492           206492
# 1             1026           1026             4104             4104
# 2              324            324             1764             1764
# 3               21             21               42               42
# 4              948            948            67150            67150
#
#    feature_sa203  feature_seki204  feature_shou204  feature_sa204  \
# 0         206492             1786             1786           1786
# 1           4104              270              270            270
# 2           1764              216              216            216
# 3             42               21               21             21
# 4          67150              158              158            158
#
#    feature_seki205  feature_shou205  feature_sa205  feature_seki206  \
# 0             2318             2318           2318             1596
# 1            14094            14094          14094             1890
# 2             1620             1620           1620              792
# 3              630              630            630              420
# 4            10902            10902          10902             1027
#
#    feature_shou206  feature_sa206  feature_seki207  feature_shou207  \
# 0             1596           1596              722              722
# 1             1890           1890              972              972
# 2              792            792              396              396
# 3              420            420              357              357
# 4             1027           1027                0                0
#
#    feature_sa207  feature_seki208  feature_shou208  feature_sa208  \
# 0            722             9804             9804           9804
# 1            972             2052             2052           2052
# 2            396             1188             1188           1188
# 3            357              126              126            126
# 4              0              790              790            790
#
#    feature_seki209  feature_shou209  feature_sa209  feature_seki210  \
# 0            11970            11970          11970          2989536
# 1             6966             6966           6966          3796524
# 2             1872             1872           1872          4262040
# 3              126              126            126          2834538
# 4             6557             6557           6557          8923682
#
#    feature_shou210  feature_sa210  feature_seki211  feature_shou211  \
# 0          2989536        2989536            35910            35910
# 1          3796524        3796524           372165           372165
# 2          4262040        4262040             6916             6916
# 3          2834538        2834538             1722             1722
# 4          8923682        8923682            14774            14774
#
#    feature_sa211  feature_seki212  feature_shou212  feature_sa212  \
# 0          35910                0                0              0
# 1         372165             6450             6450           6450
# 2           6916              884              884            884
# 3           1722              306              306            306
# 4          14774              498              498            498
#
#    feature_seki213  feature_shou213  feature_sa213  feature_seki214  \
# 0             2205             2205           2205     35910.000000
# 1            14319            14319          14319      7297.353027
# 2              728              728            728       384.222229
# 3             1038             1038           1038        33.115383
# 4             1411             1411           1411      2110.571533
#
#    feature_shou214  feature_sa214  feature_seki215  feature_shou215  \
# 0     35910.000000   35910.000000        19.173914        19.173914
# 1      7297.353027    7297.353027         4.961538         4.961538
# 2       384.222229     384.222229         5.432836         5.432836
# 3        33.115383      33.115383         3.604167         3.604167
# 4      2110.571533    2110.571533         7.882681         7.882681
#
#    feature_sa215  feature_seki216  feature_shou216  feature_sa216  \
# 0      19.173914      2205.000000      2205.000000    2205.000000
# 1       4.961538       280.764709       280.764709     280.764709
# 2       5.432836        40.444443        40.444443      40.444443
# 3       3.604167        19.961538        19.961538      19.961538
# 4       7.882681       201.571426       201.571426     201.571426
#
#    feature_seki217  feature_shou217  feature_sa217  feature_seki218  \
# 0            15120            15120          15120          1711710
# 1             2451             2451           2451             9804
# 2              468              468            468             2548
# 3                6                6              6               12
# 4              996              996            996            70550
#
#    feature_shou218  feature_sa218  feature_seki219  feature_shou219  \
# 0          1711710        1711710            14805            14805
# 1             9804           9804              645              645
# 2             2548           2548              312              312
# 3               12             12                6                6
# 4            70550          70550              166              166
#
#    feature_sa219  feature_seki220  feature_shou220  feature_sa220  \
# 0          14805            19215            19215          19215
# 1            645            33669            33669          33669
# 2            312             2340             2340           2340
# 3              6              180              180            180
# 4            166            11454            11454          11454
#
#    feature_seki221  feature_shou221  feature_sa221  feature_seki222  \
# 0            13230            13230          13230             5985
# 1             4515             4515           4515             2322
# 2             1144             1144           1144              572
# 3              120              120            120              102
# 4             1079             1079           1079                0
#
#    feature_shou222  feature_sa222  feature_seki223  feature_shou223  \
# 0             5985           5985            81270            81270
# 1             2322           2322             4902             4902
# 2              572            572             1716             1716
# 3              102            102               36               36
# 4                0              0              830              830
#
#    feature_sa223  feature_seki224  feature_shou224  feature_sa224  \
# 0          81270            11970            11970          11970
# 1           4902             6966             6966           6966
# 2           1716             1872             1872           1872
# 3             36              126              126            126
# 4            830             6557             6557           6557
#
#    feature_seki225  feature_shou225  feature_sa225  feature_seki226  \
# 0         24781680         24781680       24781680          8968608
# 1          9069474          9069474        9069474        202832810
# 2          6156280          6156280        6156280         15745870
# 3           809868           809868         809868         38738686
# 4          9375514          9375514        9375514         20106524
#
#    feature_shou226  feature_sa226  feature_seki227  feature_shou227  \
# 0          8968608        8968608                0                0
# 1        202832810      202832810          3515300          3515300
# 2         15745870       15745870          2012630          2012630
# 3         38738686       38738686          6883878          6883878
# 4         20106524       20106524           677748           677748
#
#    feature_sa227  feature_seki228  feature_shou228  feature_sa228  \
# 0              0           550704           550704         550704
# 1        3515300          7803966          7803966        7803966
# 2        2012630          1657460          1657460        1657460
# 3        6883878         23351194         23351194       23351194
# 4         677748          1920286          1920286        1920286
#
#    feature_seki229  feature_shou229  feature_sa229  feature_seki230  \
# 0     8.968608e+06     8.968608e+06   8.968608e+06      4788.730469
# 1     3.977114e+06     3.977114e+06   3.977114e+06      2704.076904
# 2     8.747706e+05     8.747706e+05   8.747706e+05     12369.104492
# 3     7.449748e+05     7.449748e+05   7.449748e+05     81080.531250
# 4     2.872360e+06     2.872360e+06   2.872360e+06     10727.854492
#
#    feature_shou230  feature_sa230  feature_seki231  feature_shou231  \
# 0      4788.730469    4788.730469    550704.000000    550704.000000
# 1      2704.076904    2704.076904    153018.937500    153018.937500
# 2     12369.104492   12369.104492     92081.109375     92081.109375
# 3     81080.531250   81080.531250    449061.437500    449061.437500
# 4     10727.854492   10727.854492    274326.562500    274326.562500
#
#    feature_sa231  feature_seki232  feature_shou232  feature_sa232  \
# 0  550704.000000          3776256          3776256        3776256
# 1  153018.937500          1335814          1335814        1335814
# 2   92081.109375          1065510          1065510        1065510
# 3  449061.437500           134978           134978         134978
# 4  274326.562500          1355496          1355496        1355496
#
#    feature_seki233  feature_shou233  feature_sa233  feature_seki234  \
# 0        427503648        427503648      427503648          3697584
# 1          5343256          5343256        5343256           351530
# 2          5801110          5801110        5801110           710340
# 3           269956           269956         269956           134978
# 4         96014300         96014300       96014300           225916
#
#    feature_shou234  feature_sa234  feature_seki235  feature_shou235  \
# 0          3697584        3697584          4798992          4798992
# 1           351530         351530         18349866         18349866
# 2           710340         710340          5327550          5327550
# 3           134978         134978          4049340          4049340
# 4           225916         225916         15588204         15588204
#
#    feature_sa235  feature_seki236  feature_shou236  feature_sa236  \
# 0        4798992          3304224          3304224        3304224
# 1       18349866          2460710          2460710        2460710
# 2        5327550          2604580          2604580        2604580
# 3        4049340          2699560          2699560        2699560
# 4       15588204          1468454          1468454        1468454
#
#    feature_seki237  feature_shou237  feature_sa237  feature_seki238  \
# 0          1494768          1494768        1494768         20297376
# 1          1265508          1265508        1265508          2671628
# 2          1302290          1302290        1302290          3906870
# 3          2294626          2294626        2294626           809868
# 4                0                0              0          1129580
#
#    feature_shou238  feature_sa238  feature_seki239  feature_shou239  \
# 0         20297376       20297376          2989536          2989536
# 1          2671628        2671628          3796524          3796524
# 2          3906870        3906870          4262040          4262040
# 3           809868         809868          2834538          2834538
# 4          1129580        1129580          8923682          8923682
#
#    feature_sa239  feature_seki240  feature_shou240  feature_sa240
# 0        2989536         24781680         24781680       24781680
# 1        3796524          9069474          9069474        9069474
# 2        4262040          6156280          6156280        6156280
# 3        2834538           809868           809868         809868
# 4        8923682          9375514          9375514        9375514
#
# [5 rows x 769 columns]

# %% [markdown]
# ##-- 説明変数のみ取り出す
# # data = data[input_name]
#
# ##-- 訓練データ(X)とテストデータ(X_test)に再分割
# X = data.iloc[:len(Y), :]
# X_pre = data.iloc[len(Y):, :]
#
# print(X.shape[0], X_pre.shape[0]) ##-- 19720 and 29582

# %% [markdown]
# 一度学習して寄与がない因子を特定する

# %%
###-- Import LightGBM and MultiClass logloss --###
import lightgbm as lgb
from sklearn.metrics import log_loss, mean_squared_log_error
###--  Set params  --###
params = {
          'boosting_type': 'gbdt',
          'objective': 'regression',
          'metric': 'rmse',
          'max_depth': 8,
          'num_threads': 4,
          'verbose': -1,
          #-- Optimized by Optuna
          'learning_rate': 0.07,
          'lambda_l1': 0.0057,
          'lambda_l2': 0.,
          'num_leaves': 222,
          'feature_fraction': 1.,
          'bagging_fraction': 0.93,
          'bagging_freq': 1,
          'min_child_samples': 28,
          #-- Added
          'seed': random_state,                                                                        
}
###-- データの8割を訓練に、残り2割を検証データに割り振る
rate_split = 0.8
X_train, Y_train = X.iloc[:int(len(Y)*rate_split), :], Y.iloc[:int(len(Y)*rate_split)]
X_val, Y_val = X.iloc[int(len(Y)*rate_split):, :], Y.iloc[int(len(Y)*rate_split):]
###-- Set dataset --###
train_data_set = lgb.Dataset(X_train, Y_train, categorical_feature=cat_cols, free_raw_data=False)
test_data_set = lgb.Dataset(X_val, Y_val, reference=train_data_set, categorical_feature=cat_cols)
###-- 全データ投入して学習 --###
models, loss_list = [], []

num_splits=4
from sklearn.model_selection import KFold
kf = KFold(n_splits=num_splits, shuffle=True, random_state=random_state)
##------------------------------------
for train_idx, val_idx in kf.split(X):
  ###-- Set the dataset --###
  X_kfold_train, Y_kfold_train = X.iloc[train_idx, :], Y.iloc[train_idx]
  X_kfold_val, Y_kfold_val = X.iloc[val_idx, :], Y.iloc[val_idx]

  ###-- Set dataset --###
  train_data_set = lgb.Dataset(X_kfold_train, Y_kfold_train, categorical_feature=cat_cols)
  test_data_set = lgb.Dataset(X_kfold_val, Y_kfold_val, reference=train_data_set)
  gbm = lgb.train(\
                  params,
                  train_data_set,
                  valid_names=['train', 'valid'],
                  valid_sets=test_data_set,
                  # early_stopping_rounds=20,  ##--default: 20
                  # verbose_eval=40,
                  # num_boost_round=100,
                  early_stopping_rounds=100,  ##--default: 20
                  verbose_eval=100,
                  num_boost_round=5000, #--Equaling to "n_estimators"
                  )
  models.append(gbm)

  Y_val_pre = gbm.predict(X_kfold_val)
  ##-- loss: RMSE  np.sqrt(mean_squared_log_error(np.exp(y_val), oof)) = 
  loss_rmsle = np.sqrt( mean_squared_log_error(np.exp(Y_val_pre), np.exp(Y_kfold_val)) )
  loss_list.append(loss_rmsle)
  ##-- RMSLE lossを出力
  print()
  print("RMSLE", loss_rmsle)
  print()

# %%
##-- Feature importanceの平均を各モデルごとにとる
def feature_importance(gbm):
  return pd.DataFrame({'Feature': X.columns,\
                       'importance':gbm.feature_importance(importance_type='gain')})\
                        .sort_values('importance', ascending=False)

feature, importance = [], []
for i in range(len(X.columns)):
  tem = 0.
  for j in range(len(models)):
  # for j in range(num_models):
    feature_imp = feature_importance(models[j])
    tem = tem + feature_imp["importance"][i]
  tem = tem / len(models)
  importance.append(tem)
  name = feature_imp["Feature"][i]
  feature.append(name)

##-- 寄与がゼロの"Feature"をpick up
f_imp = pd.DataFrame({'Feature': feature, 'importance': importance})
f_imp = f_imp[ f_imp["importance"] == 0. ]
f_imp["Feature"]
# Out:
# 46     freq_categoryId
# 50       feature_shou1
# 51         feature_sa1
# 53       feature_shou2
# 54         feature_sa2
#             ...
# 764    feature_shou239
# 765      feature_sa239
# 766    feature_seki240
# 767    feature_shou240
# 768      feature_sa240
# Name: Feature, Length: 602, dtype: object

# %%
##-- Drop対象になったカテゴリカル変数を落としておく
##-- カテゴリカル変数
cat_cols = [\
              #-- "***"(int64)
              "categoryId",\
              # "freq_categoryId",\
              "freq_channelTitle",\
              "onEn_tags",\
              "onEn_description",\
              "ishttp_in_dis",\
            ]

# %%
##-- 寄与がゼロの"Feature"をDrop
print("Before:", len(data.columns))
data = data.drop(columns=f_imp["Feature"])
print("Before:", len(data.columns))
# Out:
# Before: 769
# Before: 167

# %%
##-- 訓練データ(X)とテストデータ(X_test)に再分割
X = data.iloc[:len(Y), :]
X_pre = data.iloc[len(Y):, :]

print(X.shape[0], X_pre.shape[0]) ##-- 19720 and 29582
# Out:
# 19720 29582

# %%
###-- Import LightGBM and MultiClass logloss --###
import lightgbm as lgb
from sklearn.metrics import log_loss, mean_squared_log_error

###--  Set params  --###
params = {
          'boosting_type': 'gbdt',
          'objective': 'regression',
          'metric': 'rmse',
          'max_depth': 8,
          'num_threads': 4,
          'verbose': -1,
          #-- Optimized by Optuna
          'learning_rate': 0.07,
          'lambda_l1': 0.0057,
          'lambda_l2': 0.,
          'num_leaves': 222,
          'feature_fraction': 1.,
          'bagging_fraction': 0.93,
          'bagging_freq': 1,
          'min_child_samples': 28,
          #-- Added
          'seed': random_state,                                                                        
}

###-- 全データ投入して学習 --###
models, loss_list = [], []
num_models = 50
i = 1
for i in range(num_models):
  params["seed"] = random_state + i
  print()
  print("Random seed:", params["seed"])
  print()
  ###-- KFold Cross validation --###
  num_splits=5
  from sklearn.model_selection import KFold
  kf = KFold(n_splits=num_splits, shuffle=True, random_state=random_state + i)
  ##------------------------------------
  for train_idx, val_idx in kf.split(X):
    ###-- Set the dataset --###
    X_kfold_train, Y_kfold_train = X.iloc[train_idx, :], Y.iloc[train_idx]
    X_kfold_val, Y_kfold_val = X.iloc[val_idx, :], Y.iloc[val_idx]

    ###-- Set dataset --###
    train_data_set = lgb.Dataset(X_kfold_train, Y_kfold_train, categorical_feature=cat_cols)
    test_data_set = lgb.Dataset(X_kfold_val, Y_kfold_val, reference=train_data_set)
    gbm = lgb.train(\
                    params,
                    train_data_set,
                    valid_names=['train', 'valid'],
                    valid_sets=test_data_set,
                    # early_stopping_rounds=20,  ##--default: 20
                    # verbose_eval=40,
                    # num_boost_round=100,
                    early_stopping_rounds=100,  ##--default: 20
                    verbose_eval=100,
                    num_boost_round=5000, #--Equaling to "n_estimators"
                    )
    models.append(gbm)

    Y_val_pre = gbm.predict(X_kfold_val)
    ##-- loss: RMSE  np.sqrt(mean_squared_log_error(np.exp(y_val), oof)) = 
    loss_rmsle = np.sqrt( mean_squared_log_error(np.exp(Y_val_pre), np.exp(Y_kfold_val)) )
    loss_list.append(loss_rmsle)
    ##-- RMSLE lossを出力
    print()
    print("RMSLE", loss_rmsle)
    print()

# %%
print("train-average loss:", np.array(loss_list).sum() / len(models))
# Out:
# train-average loss: 0.7832494778692478

# %%
##-- Feature importanceの平均を各モデルごとにとる
def feature_importance(gbm):
  return pd.DataFrame({'Feature': X.columns,\
                       'importance':gbm.feature_importance(importance_type='gain')})\
                        .sort_values('importance', ascending=False)

feature, importance = [], []
for i in range(len(X.columns)):
  tem = 0.
  for j in range(len(models)):
  # for j in range(num_models):
    feature_imp = feature_importance(models[j])
    tem = tem + feature_imp["importance"][i]
  tem = tem / num_models
  importance.append(tem)
  name = feature_imp["Feature"][i]
  feature.append(name)

pd.DataFrame({'Feature': feature, 'importance': importance})
# Out:
#                     Feature    importance
# 0                categoryId  1.817735e+04
# 1                     likes  5.795640e+04
# 2                  dislikes  8.119097e+03
# 3             comment_count  4.430287e+03
# 4         comments_disabled  1.767179e+03
# 5          ratings_disabled  2.014543e+05
# 6        like_dislike_ratio  2.131416e+03
# 7       comments_like_ratio  2.052279e+03
# 8    comments_dislike_ratio  5.970036e+02
# 9                 likes_com  1.525885e+02
# 10             dislikes_com  3.892218e+01
# 11           comments_likes  5.768830e+02
# 12                 num_tags  1.117720e+03
# 13              length_tags  1.881606e+03
# 14               tags_point  2.636347e+03
# 15             count_en_tag  8.254889e+02
# 16         publishedAt_year  7.723756e+03
# 17        publishedAt_month  2.835743e+03
# 18          publishedAt_day  4.732129e+03
# 19         publishedAt_hour  6.915242e+03
# 20       publishedAt_minute  6.081143e+03
# 21       publishedAt_second  5.298197e+03
# 22    publishedAt_dayofweek  2.355500e+03
# 23     collection_date_year  6.144492e+00
# 24    collection_date_month  3.764142e+03
# 25      collection_date_day  1.921461e+03
# 26                    delta  3.694623e+04
# 27          published_delta  9.772913e+03
# 28         collection_delta  2.940560e+03
# 29            ishttp_in_dis  3.142351e+03
# 30          len_description  3.838351e+03
# 31                len_title  3.515192e+03
# 32                onEn_tags  2.711185e+01
# 33         onEn_description  3.112741e+00
# 34              conEn_title  4.072738e+03
# 35               conEn_tags  1.971488e+03
# 36        conEn_description  3.317219e+03
# 37                     mean  1.198508e+04
# 38                      max  5.155136e+03
# 39                      min  2.905320e+03
# 40                      std  4.009956e+03
# 41                       q1  2.954904e+04
# 42                      q25  9.422098e+02
# 43                       q5  2.243210e+03
# 44                      q75  2.783223e+03
# 45                       q9  1.480895e+03
# 46        freq_channelTitle  4.996932e+04
# 47              period_hour  5.718183e+03
# 48            feature_seki1  2.040527e+06
# 49            feature_seki2  9.356334e+02
# 50            feature_seki3  9.664904e+03
# 51            feature_seki4  2.363595e+02
# 52            feature_seki5  8.186380e+02
# 53            feature_seki6  3.558855e+03
# 54            feature_seki7  3.186359e+03
# 55            feature_seki8  1.103171e+03
# 56            feature_seki9  3.790488e+03
# 57           feature_seki10  6.788612e+04
# 58           feature_seki11  1.733063e+03
# 59           feature_seki12  9.960999e+02
# 60           feature_seki13  1.467717e+03
# 61           feature_seki14  2.532422e+03
# 62           feature_seki15  3.622760e+04
# 63           feature_seki17  1.012112e+03
# 64           feature_seki18  8.885017e+03
# 65           feature_seki19  1.195554e+03
# 66           feature_seki20  2.357712e+02
# 67           feature_seki21  1.561959e+03
# 68           feature_seki22  1.710728e+03
# 69           feature_seki23  6.531771e+02
# 70           feature_seki24  1.922360e+03
# 71           feature_seki25  2.359447e+03
# 72           feature_seki26  1.257340e+03
# 73           feature_seki27  9.516893e+02
# 74           feature_seki28  1.235159e+03
# 75           feature_seki29  1.112979e+03
# 76           feature_seki30  5.879715e+04
# 77           feature_seki34  1.237556e+03
# 78           feature_seki35  9.024614e+02
# 79           feature_seki36  1.405389e+03
# 80           feature_seki37  1.276369e+03
# 81           feature_seki38  6.989565e+02
# 82           feature_seki39  2.092346e+03
# 83           feature_seki40  2.863971e+03
# 84           feature_seki41  1.269497e+03
# 85           feature_seki42  1.435420e+03
# 86           feature_seki43  2.072741e+03
# 87           feature_seki44  1.973193e+03
# 88           feature_seki45  4.739791e+03
# 89           feature_seki49  3.214920e+02
# 90           feature_seki50  7.955798e+02
# 91           feature_seki51  2.127061e+03
# 92           feature_seki52  2.063221e+03
# 93           feature_seki53  1.394586e+03
# 94           feature_seki54  2.257476e+03
# 95           feature_seki55  4.047192e+03
# 96           feature_seki56  2.317650e+03
# 97           feature_seki57  1.478101e+03
# 98           feature_seki58  1.624094e+03
# 99           feature_seki59  2.573669e+03
# 100          feature_seki60  8.222992e+03
# 101          feature_seki65  1.074547e+03
# 102          feature_seki66  7.795244e+02
# 103          feature_seki67  1.020357e+03
# 104          feature_seki68  1.223034e+03
# 105          feature_seki69  1.245425e+03
# 106          feature_seki70  1.396651e+03
# 107          feature_seki71  2.434885e+03
# 108          feature_seki72  2.117492e+03
# 109          feature_seki73  2.102450e+03
# 110          feature_seki74  9.537801e+02
# 111          feature_seki75  2.448948e+03
# 112          feature_seki81  6.242371e+02
# 113          feature_seki82  7.268256e+02
# 114          feature_seki83  5.746119e+02
# 115          feature_seki84  6.831180e+02
# 116          feature_seki85  8.593540e+02
# 117          feature_seki86  9.462424e+02
# 118          feature_seki87  1.180651e+03
# 119          feature_seki88  9.444753e+02
# 120          feature_seki89  8.413607e+02
# 121          feature_seki90  1.122072e+03
# 122          feature_seki97  2.880651e+03
# 123          feature_seki98  1.522096e+03
# 124          feature_seki99  2.592916e+03
# 125         feature_seki100  2.676212e+03
# 126         feature_seki101  1.888495e+03
# 127         feature_seki102  1.071771e+03
# 128         feature_seki103  1.893071e+03
# 129         feature_seki104  1.678369e+03
# 130         feature_seki105  5.692100e+03
# 131         feature_seki113  1.589057e+03
# 132         feature_seki114  4.400175e+03
# 133         feature_seki115  2.741017e+03
# 134         feature_seki116  3.683272e+03
# 135         feature_seki117  1.802242e+03
# 136         feature_seki118  4.054706e+03
# 137         feature_seki119  3.910153e+03
# 138         feature_seki120  4.170082e+03
# 139         feature_seki129  2.882687e+03
# 140         feature_seki130  1.915843e+03
# 141         feature_seki131  4.176635e+03
# 142         feature_seki132  1.265699e+03
# 143         feature_seki133  2.622556e+03
# 144         feature_seki134  1.138285e+03
# 145         feature_seki135  4.329750e+03
# 146         feature_seki145  3.575768e+03
# 147         feature_seki146  2.461296e+03
# 148         feature_seki147  6.266824e+03
# 149         feature_seki148  2.655774e+03
# 150         feature_seki149  3.271894e+03
# 151         feature_seki150  5.998900e+03
# 152         feature_seki161  2.790191e+03
# 153         feature_seki162  2.533606e+03
# 154         feature_seki163  2.739739e+03
# 155         feature_seki164  3.429282e+03
# 156         feature_seki165  7.887042e+03
# 157         feature_seki177  3.642602e+03
# 158         feature_seki178  5.658233e+03
# 159         feature_seki179  1.475749e+03
# 160         feature_seki180  1.149195e+04
# 161         feature_seki193  3.207606e+03
# 162         feature_seki194  1.286507e+03
# 163         feature_seki195  4.013372e+03
# 164         feature_seki209  2.448358e+03
# 165         feature_seki210  4.824456e+03
# 166         feature_seki225  4.846997e+03

# %%
def predict_ensemble(models, num_model, X_pre):
    Y_pre_list = []
    for i in range(num_model):
        Y_pre = models[i].predict(X_pre)
        Y_pre_list.append(Y_pre)

    Y_pre_list = np.array(Y_pre_list)

    Y_pre_submit_tem = Y_pre_list[0]
    for i in range(1, num_model):
        Y_pre_submit_tem += Y_pre_list[i]

    Y_pre_submit = Y_pre_submit_tem / float(num_model)

    return Y_pre_submit


###------------------------------------###
###        結果ファイルへの書き出し        ###
###------------------------------------###
from pathlib import Path
root = Path(PATH_submit)

##-- Prediction for test data
Y_pre_submit = np.exp(predict_ensemble(models, len(models), X_pre))

submit = pd.DataFrame({'y': Y_pre_submit})
submit.index.name = 'id'
submit.index = submit.index + 1
submit.to_csv(root.joinpath("submission_lightgbm_5kfold_Seed"+str(random_state+1)+"-"+str(random_state+num_models)+".csv"), index=True)
